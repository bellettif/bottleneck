# %%
## Useful imports

# %%
from datetime import datetime
from datetime import timedelta
import numpy as np
import pandas as pd
import sys
import os
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import cPickle as pickle
import scipy
import scipy.sparse.linalg
# %matplotlib inline

from datetime import datetime

# %%
input_data_folder = '../../data/processed/'

data_files = filter(lambda x: x[-4:] == '.csv', os.listdir(input_data_folder))

# %%
print data_files
# Out:
# ['nfbVD-5N-0.178.csv', 'nfbVD-5N-0.706.csv', 'nfbVD-5N-13.348.csv', 'nfbVD-5N-13.763.csv', 'nfbVD-5N-14.550.csv', 'nfbVD-5N-14.800.csv', 'nfbVD-5N-28.420.csv', 'nfbVD-5N-30.100.csv', 'nfbVD-5N-4.058.csv', 'nfbVD-5N-4.400.csv', 'nfbVD-5N-4.460.csv', 'nfbVD-5N-5.523.csv', 'nfbVD-5N-5.883.csv', 'nfbVD-5N-6.413.csv', 'nfbVD-5N-7.113.csv', 'nfbVD-5N-7.636.csv', 'nfbVD-5N-8.043.csv', 'nfbVD-5N-8.703.csv', 'nfbVD-5N-9.013.csv', 'nfbVD-5N-PLIC-I-14.583.csv', 'nfbVD-5N-PLIC-O-14.683.csv', 'nfbVD-5N-PST-10.147.csv', 'nfbVD-5N-PST-10.506.csv', 'nfbVD-5N-PST-11.178.csv', 'nfbVD-5N-PST-11.555.csv', 'nfbVD-5N-PST-12.238.csv', 'nfbVD-5N-PST-12.579.csv', 'nfbVD-5N-PST-12.922.csv', 'nfbVD-5N-PST-9.373.csv', 'nfbVD-5N-PST-9.840.csv', 'nfbVD-5N-PST-P-10.866.csv', 'nfbVD-5N-PST-P-11.896.csv', 'nfbVD-5N-SDIC-I-4.044.csv', 'nfbVD-5N-SDIC-O-4.455.csv', 'nfbVD-5N-SDT-1.068.csv', 'nfbVD-5N-SDT-1.435.csv', 'nfbVD-5N-SDT-1.788.csv', 'nfbVD-5N-SDT-2.068.csv', 'nfbVD-5N-SDT-2.455.csv', 'nfbVD-5N-SDT-2.849.csv', 'nfbVD-5N-SDT-3.198.csv', 'nfbVD-5N-SST-15.488.csv', 'nfbVD-5N-SST-15.855.csv', 'nfbVD-5N-SST-16.196.csv', 'nfbVD-5N-SST-16.570.csv', 'nfbVD-5N-SST-17.268.csv', 'nfbVD-5N-SST-17.608.csv', 'nfbVD-5N-SST-17.998.csv', 'nfbVD-5N-SST-18.662.csv', 'nfbVD-5N-SST-19.012.csv', 'nfbVD-5N-SST-19.361.csv', 'nfbVD-5N-SST-20.062.csv', 'nfbVD-5N-SST-20.412.csv', 'nfbVD-5N-SST-20.752.csv', 'nfbVD-5N-SST-21.444.csv', 'nfbVD-5N-SST-21.808.csv', 'nfbVD-5N-SST-22.158.csv', 'nfbVD-5N-SST-22.859.csv', 'nfbVD-5N-SST-23.209.csv', 'nfbVD-5N-SST-23.568.csv', 'nfbVD-5N-SST-24.264.csv', 'nfbVD-5N-SST-24.677.csv', 'nfbVD-5N-SST-24.952.csv', 'nfbVD-5N-SST-25.652.csv', 'nfbVD-5N-SST-26.007.csv', 'nfbVD-5N-SST-26.300.csv', 'nfbVD-5N-SST-27.056.csv', 'nfbVD-5N-SST-27.468.csv', 'nfbVD-5N-SST-27.779.csv', 'nfbVD-5N-SST-P-16.900.csv', 'nfbVD-5N-SST-P-18.313.csv', 'nf
# %%
northbound_files = filter(lambda x: '5N' in x, data_files)
southbound_files = filter(lambda x : '5S' in x, data_files)

# %%
def extract_km(in_filename):
    return float(x.split('-')[-1][:-4])

# %%
northbound_data = [(x, extract_km(x), pd.read_csv(input_data_folder + x, na_values = '-1')) 
                   for x in northbound_files]
southbound_data = [(x, extract_km(x), pd.read_csv(input_data_folder + x, na_values = '-1')) 
                   for x in southbound_files]

northbound_data.sort(key = (lambda x : x[1]))
southbound_data.sort(key = (lambda x : x[1]))

# %%
northbound_data[0][2]
# Out:
#                  vdid  status            timestamp  speed  occupy   S  T  L  \
# 0      nfbVD-5N-0.178       0  2015/03/31 23:50:00   83.5     1.0  21  2  0
# 1      nfbVD-5N-0.178       0  2015/04/01 00:10:00   81.0     0.0  16  0  0
# 2      nfbVD-5N-0.178       0  2015/04/01 00:15:00   85.5     1.0  16  1  0
# 3      nfbVD-5N-0.178       0  2015/04/01 00:25:00   81.0     0.0  14  0  0
# 4      nfbVD-5N-0.178       0  2015/04/01 00:30:00   89.5     0.0  14  0  0
# 5      nfbVD-5N-0.178       0  2015/04/01 00:40:00   90.0     0.0  14  0  0
# 6      nfbVD-5N-0.178       0  2015/04/01 00:45:00   85.0     0.5  21  1  0
# 7      nfbVD-5N-0.178       0  2015/04/01 00:50:00   84.5     0.0  15  0  0
# 8      nfbVD-5N-0.178       0  2015/04/01 00:55:00   80.0     0.5  14  0  0
# 9      nfbVD-5N-0.178       0  2015/04/01 01:00:00   84.0     0.0  11  0  0
# 10     nfbVD-5N-0.178       0  2015/04/01 01:05:00   84.5     0.0  11  0  0
# 11     nfbVD-5N-0.178       0  2015/04/01 01:20:00   81.5     0.0   4  0  0
# 12     nfbVD-5N-0.178       0  2015/04/01 01:30:00   92.5     0.0   5  0  0
# 13     nfbVD-5N-0.178       0  2015/04/01 01:35:00   85.5     0.5  15  1  0
# 14     nfbVD-5N-0.178       0  2015/04/01 01:45:00   85.0     0.0  12  0  0
# 15     nfbVD-5N-0.178       0  2015/04/01 01:55:00   80.5     0.0  13  0  0
# 16     nfbVD-5N-0.178       0  2015/04/01 02:05:00   98.0     0.0  13  0  0
# 17     nfbVD-5N-0.178       0  2015/04/01 02:10:00   90.0     0.0  10  0  0
# 18     nfbVD-5N-0.178       0  2015/04/01 02:15:00   84.5     0.0  15  0  0
# 19     nfbVD-5N-0.178       0  2015/04/01 02:20:00   88.0     0.5  10  0  0
# 20     nfbVD-5N-0.178       0  2015/04/01 02:45:00   81.5     0.0   8  0  0
# 21     nfbVD-5N-0.178       0  2015/04/01 02:50:00   83.5     0.0   5  0  0
# 22     nfbVD-5N-0.178       0  2015/04/01 03:15:00   86.5     0.0   7  0  0
# 23     nfbVD-5N-0.178       0  2015/04/01 03:20:00   82.0     0.0   7  0  0
# 24     nfbVD-5N-0.178       0  2015/04/01 08:05:00   84.0     3.5  53  5  0
# 25     nfbVD-5N-0.178       0  2015/04/01 08:20:00   83.5     2.5  37  5  0
# 26     nfbVD-5N-0.178       0  2015/04/01 08:25:00   84.5     2.5  42  4  0
# 27     nfbVD-5N-0.178       0  2015/04/01 22:55:00   83.0     2.0  38  2  0
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# 5               2
# 6               2
# 7               2
# 8               2
# 9               2
# 10              2
# 11              2
# 12              2
# 13              2
# 14              2
# 15              2
# 16              2
# 17              2
# 18              2
# 19              2
# 20              2
# 21              2
# 22              2
# 23              2
# 24              2
# 25              2
# 26              2
# 27              2
# 28              2
# 29              2
# ...           ...
# 23107           2
# 23108           2
# 23109           2
# 23110           2
# 23111           2
# 23112           2
# 23113           2
# 23114           2
# 23115           2
# 23116           2
# 23117           2
# 23118           2
# 23119           2
# 23120           2
# 23121           2
# 23122           2
# 23123           2
# 23124           2
# 23125           2
# 23126           2
# 23127           2
# 23128           2
# 23129           2
# 23130           2
# 23131           2
# 23132           2
# 23133           2
# 23134           2
# 23135           2
# 23136           2
#
# [23137 rows x 9 columns]

# %%
flow_map = []
speed_map = []
lane_count = []

for (sensor, km, df) in southbound_data:
    """
    if 'SDT' in sensor:
        continue
        
    if 'PST' in sensor:
        continue
        
    if 'SST' in sensor:
        continue
        
    if 'TCIC' in sensor:
        continue
        
    if 'SDIC' in sensor:
        continue
        
    if 'PLIC' in sensor:
        continue
    """
    
    df = df[df['lane_count'] == 2]    
        
    df.index = df['timestamp']    
    df.sort('timestamp', inplace = True)    
    
    flow_map.append(df['S'])
    speed_map.append(df['speed'])
    lane_count.append(df['lane_count'])
    
    df[:'2015/04/15'].plot('timestamp', 'S', linestyle = 'None', marker = '.')
    plt.show()
    
    df[:'2015/04/15'].hist('status')
    plt.show()
    
    df.plot('S', 'speed', linestyle = 'None', marker = 'o', alpha = 0.1)
    plt.title(sensor)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-6ca1d7f615f3> in <module>()
#      24     """
#      25
# ---> 26     df = df[df['lane_count'] == 2, :]
#      27
#      28     df.index = df['timestamp']
#
# /usr/local/lib/python2.7/site-packages/pandas-0.16.2-py2.7-macosx-10.10-x86_64.egg/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas-0.16.2-py2.7-macosx-10.10-x86_64.egg/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /usr/local/lib/python2.7/site-packages/pandas-0.16.2-py2.7-macosx-10.10-x86_64.egg/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1080         """ return the cached item, item represents a label indexer """
#    1081         cache = self._item_cache
# -> 1082         res = cache.get(item)
#    1083         if res is None:
#    1084             values = self._data.get(item)
#
# /usr/local/lib/python2.7/site-packages/pandas-0.16.2-py2.7-macosx-10.10-x86_64.egg/pandas/core/generic.pyc in __hash__(self)
#     661     def __hash__(self):
#     662         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# --> 663                         ' hashed'.format(self.__class__.__name__))
#     664
#     665     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
n_x = len(flow_map)
n_t = len(flow_map[0])

# %%
print len(flow_map)
print len(flow_map[0])

print len(southbound_data)
# Out:
# 9
# 23137
# 78

# %%
flow_matrix = np.asanyarray(flow_map)
speed_matrix = np.asanyarray(speed_map)

# %%
plt.figure(figsize = (10, 10))
plt.subplot(211)
plt.imshow(speed_matrix[:,9000:9400], aspect='auto')
plt.colorbar()
plt.subplot(212)
plt.imshow(lane_count, aspect = 'auto')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-02a41cbcb627> in <module>()
#       1 plt.figure(figsize = (10, 10))
#       2 plt.subplot(211)
# ----> 3 plt.imshow(speed_matrix[:,9000:9400], aspect='auto')
#       4 plt.colorbar()
#       5 plt.subplot(212)
#
# IndexError: too many indices for array

# %%
plt.figure(figsize = (10, 10))
plt.subplot(211)
plt.imshow(flow_matrix[:,9000:9400], aspect='auto')
plt.colorbar()
plt.subplot(212)
plt.imshow(lane_count, aspect = 'auto')
plt.colorbar()

# %%
print flow_matrix.shape
# Out:
# (9,)
